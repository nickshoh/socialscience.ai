# %% [markdown]
# **Visualize**

# %%
weight, bias = -3, -3

# %%
for i in range (0,25): 
    fig = plt.figure(figsize=(30,30))
    ax = fig.add_subplot(5,5,i+1,projection = '3d')
    
    w = np.linspace(-5, 5, 10)
    b = np.linspace(-5, 5, 10)
    w, b = np.meshgrid(w, b)
    
    def L(w,b): 
        return (y[0,i]**2) - 2*(x[0,i]*y[0,i])*w - 2*(y[0,i])*b + (x[0,i]**2)*(w**2) + 2*(x[0,i])*w*b + b**2
    
    ax.plot_surface(w, b, L(w,b), rstride=1, cstride=1,
                cmap='winter', edgecolor='none', alpha=.5)
    ax.plot_wireframe(w, b, L(w,b), color='grey', alpha=.5)
    
    ax.scatter(weight, bias, L(weight,bias), color='red', marker ='o')
    
    ax.set_xlabel('w')
    ax.set_ylabel('b')
    ax.set_zlabel('L{}(w,b)'.format(i+1))
# Out:
# C:\Users\Nick Oh\anaconda3\lib\site-packages\ipykernel_launcher.py:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).

# %%
visualize.loss(feature =
# Out:
# (1.9393002879418835, 3.760885606811472, 1.111532506532133)

# %%
# import numpy as np 
# import matplotlib.pylab as plt
# from mpl_toolkits import mplot3d

class visualize: 
    
    def __init__(self): 
        self.w = None
        self.b = None 
    
    def loss(self, epoch, sample, feature):
        self.epoch = epoch 
        self.sample = sample 
        self.feature = feature 
        
        def OLS(w,b): 
            y_hat = w*x[self.feature, self.sample] + b 
            loss = (y[self.feature, self.sample] - y_hat)**2
            return loss
        
        fig = plt.figure(figsize=(5,5))
        ax = plt.axes(projection='3d')
        
        w = np.linspace(-5,5,10)
        b = np.linspace(-5,5,10)
        w, b = np.meshgrid(w,b)
        
        ax.plot_surface(w, b, OLS(w,b), rstride=1, cstride=1,
                        cmap='winter', edgecolor='none', alpha=.5)
        ax.plot_wireframe(w, b, OLS(w,b), color='grey', alpha=.5)
        ax.scatter(weight, bias, OLS(weight,bias), color='red', marker ='o')
        
        return plt.show()

# %%
fig = plt.figure()
ax = plt.axes(projection='3d')
    
w = np.linspace(-5, 5, 10)
b = np.linspace(-5, 5, 10)
w, b = np.meshgrid(w, b)
    
def J(w,b):
    return np.sum(df['y']**2) - np.sum(2*df['x']*df['y'])*w - np.sum(2*df['y'])*b + np.sum(df['x']**2)*(w**2) + np.sum(2*df['x'])*w*b + b**2
    
ax.plot_surface(w, b, J(w,b), rstride=1, cstride=1,
                cmap='winter', edgecolor='none', alpha=.5)
ax.plot_wireframe(w, b, J(w,b), color='grey', alpha=.5)
    
ax.scatter(weight, bias, J(weight,bias), c='red')
    
ax.set_xlabel('w')
ax.set_ylabel('b')
ax.set_zlabel('J(w,b)')
# Out:
# Text(0.5, 0, 'J(w,b)')
